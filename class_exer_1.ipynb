# %% [markdown]
# <a href="https://colab.research.google.com/github/yuvanbenaditraja-ui/class-exercise_1/blob/main/class_exer_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 BankAccount:
 class def __init__(self, account_holder, balance=0):
    self.account_holder = account_holder
    self.balance = balance
    self.transactions = []

  def deposit(self, amount):
    if amount > 0:
      self.balance += amount
      self.transactions.append(f"Deposit: ${amount}")
      print(f"Deposited: ${amount}. New balance: ${self.balance}")
    else:
      print("Invalid deposit amount.")

  def withdraw(self, amount):
    if 0 < amount <= self.balance:
      self.balance -= amount
      self.transactions.append(f"Withdraw: {amount}")
      print(f"Withdrew: ${amount}. New balance: {self.balance}")
    else:
      print(f"Invalid withdrawal amount or insufficient balance. Current balance: {self.balance}")

  def checkbalance(self):
    print(f"Current balance: {self.balance}")

  def display_statement(self):
    print(f"\n-- Statement for {self.account_holder} --")
    if not self.transactions:
        print("No transactions yet.")
    for transaction in self.transactions:
        print(transaction)
    print(f"Current balance: {self.balance}")
    print("---------------------")

account = BankAccount("yuvan", 1000)
account.display_statement()
account.deposit(500)
account.checkbalance()
account.withdraw(200)
account.display_statement()
# Out:
#   File "<tokenize>", line 7
#     def deposit(self, amount):
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
class bankaccount:
  def __init_(self,account_holder,balance=0):
    self.account_holder=account_holder
    self.balnce=balance

  def deposite(self,amount):
    if amount>0:
      self.balance+= balance
      print("deposite amount",{amount})
    else:
      print("invalid amountor insufficent amount")

  def withdrawal (self,amount):
       if 0 <amount<=self.balance:
         self.balance-=amount
       else:
         print("inavlid amount")

  def checkbalance(self):
        print(self.account_holder,"balance")

# %%
class shape:
    def __init__ (self,length=0,width=0):
       self.length=length
       self.width=width

def get_area(self):
    return 0
def display(self):
    print(f"shape with length={self.length},width={self.width}")



    class rectangle(shape):
      def __init__(self,length,width):
           super() ._init_(length,width)



    def get_area(self):
      return self.length*self.width
    def display(self):
     print(f"rectangle area ={self.get_area()}")


     class circle(shape):
        def _init_(self,radius):
          super().intit_(radius,0)
          self.radius=radius

          def get_area(self):
              return math.pi *  self.radius

        def display(self):
          print(f"circle:radius={self.radius},area={self.get_area}")



        def main():
            rect=rectangle(5,4)
            circ=circle(3)

            rectangle.display()
            circle.display()
print("rectangle  area",rect.get_area())
print("circle area",circle.get_area())



shapes=[rectangle(5,4),circle(3)]
for shape in shapes:
            shape.display()


if __name__=="__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-199/3358812102.py in <cell line: 0>()
#      55
#      56 if __name__=="__main__":
# ---> 57       main()
#      58
#      59
#
# NameError: name 'main' is not defined

# %%
class Member:
    def __init__(self, name, membership_id):
        self.name = name
        self.membership_id = membership_id

    def display(self):

        print(f"Name: {self.name}")
        print(f"Membership ID: {self.membership_id}")

    def get_borrow_limit(self):

        raise NotImplementedError("Subclasses must implement this method")


class RegularMember(Member):
    def __init__(self, name, membership_id):
        super().__init__(name, membership_id)
        self.borrow_limit = 3

    def get_borrow_limit(self):
        return self.borrow_limit

    def display(self):
        super().display()
        print("Membership Type: Regular")
        print(f"Borrowing Limit: {self.get_borrow_limit()} books")



def main():
    member1 = RegularMember("yuvan", 101)
    member1.display()



if __name__ == "__main__":
    main()
# Out:
# Name: Alice
# Membership ID: 101
# Membership Type: Regular
# Borrowing Limit: 3 books

# %%
class Student:
    def __init__(self, name, roll_number):
        self.name = name
        self.roll_number = roll_number

    def display(self):
        print(f"Name: {self.name}")
        print(f"Roll Number: {self.roll_number}")

class UndergraduateStudent(Student):
    def __init__(self, name, roll_number, marks):

        super().__init__(name, roll_number)
        self.marks = marks[:3]

    def calculate_average(self):
        return sum(self.marks) / len(self.marks)

    def display(self):
        print("--- Undergraduate Result ---")
        print(f"Student Name: {self.name}")
        print(f"Average Marks: {self.calculate_average():.2f}")

class PostgraduateStudent(Student):
    def __init__(self, name, roll_number, marks):

        super().__init__(name, roll_number)
        self.marks = marks[:4]

    def calculate_average(self):
        return sum(self.marks) / len(self.marks)

    def display(self):
        print("\n--- Postgraduate Result ---")
        print(f"Student Name: {self.name}")
        print(f"Average Marks: {self.calculate_average():.2f}")


if __name__ == "__main__":

    ug_marks = [85.5, 90.0, 78.0]
    ug_student = UndergraduateStudent("Alice Johnson", 101, ug_marks)


    pg_marks = [88.0, 92.5, 80.0, 95.0]
    pg_student = PostgraduateStudent("Bob Smith", 501, pg_marks)


    ug_student.display()
    pg_student.display()
# Out:
# --- Undergraduate Result ---
# Student Name: Alice Johnson
# Average Marks: 84.50
#
# --- Postgraduate Result ---
# Student Name: Bob Smith
# Average Marks: 88.88
